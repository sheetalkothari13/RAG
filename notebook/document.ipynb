# %% [markdown]
# # Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is a test document. main content to create rag",
    metadata={
        "source": "test.txt",
        "pages" : 1,
        "author" : "SK"
        }
)

# %%
doc
# Out:
# Document(metadata={'source': 'test.txt', 'pages': 1, 'author': 'SK'}, page_content='This is a test document. main content to create rag')

# %% [markdown]
# ## Simple txt file

# %%
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text = {
    "../data/text_files/python_intro.txt":""" Python programming intro
    Concept:
Data is raw, unprocessed facts — numbers, characters, or signals — that by themselves carry no context (e.g.,
72, 'Ravi', 08). Information is data that has been processed, organized, or structured so it becomes meaningful
and useful for decision-making (e.g., 'Ravi scored 72 marks on 08-06-2026'). The transformation of data into
information happens through processing: sorting, classifying, summarizing, and calculating. Key properties of
good information are accuracy, timeliness, completeness, relevance, and reliability. In the
data-information-knowledge-wisdom (DIKW) hierarchy, data sits at the base, information is data with context,
knowledge is information with understanding of patterns, and wisdom is knowledge applied with judgement.
CPGET frequently tests the distinction between data and information, examples of each, and characteristics of
quality information.

Practice Questions:
Q1. Which of the following is an example of 'information' rather than raw 'data'?
Solution: 'The average monthly rainfall in Hyderabad in June is 120 mm' is information because raw daily
rainfall readings have been processed (averaged) and given context. A single reading like '15 mm' alone is data.
Q2. List three properties that make information 'good quality' for decision-making.
Solution: Accuracy (free from errors), Timeliness (available when needed), and Relevance (applicable to the
decision at hand). Completeness and reliability are also acceptable answers.
Q3. Explain with one example how the same data can produce different information for different users.
Solution: Sales figures (data) of a shop can be processed into 'total monthly revenue' for an owner, or into
'best-selling product' for a marketing team — same raw data, different processing goals, different information.

Previous Year Questions:
1. Data can best be described as:\n(A) Processed facts \n(B) Raw, unorganized facts \n(C) Knowledge derived
from experience \n(D) A decision-making tool
Answer: (B)
2. Which term refers to data that has been given context and meaning?\n(A) Database \n(B) Information \n(C)Algorithm \n(D) Protocol
Answer: (B)
3. In the DIKW hierarchy, which level comes immediately above 'Data'?\n(A) Wisdom \n(B) Knowledge \n(C)Information \n(D) Intelligence
Answer: (C)

    """
}

for file_path, content in sample_text.items():
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(content)

print("sample text created")
# Out:
# sample text created

# %% [markdown]
# ## Text loader

# %%
# from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# C:\Users\kotha\AppData\Local\Temp\ipykernel_25732\3599593742.py:4: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# ...

# %%
# !pip install langchain-community

# %%
sample_text = {
    "../data/text_files/ML_intro.txt":""" ML intro
Machine Learning is a technique that allows computers to learn from data and make decisions without explicit programming. It works by identifying patterns in data and using them to make predictions. It is used in areas such as:

Image Recognition
Speech Processing
Language Translation
Recommender Systems

Need for Machine Learning
Machine Learning is important because traditional programming cannot handle complex tasks or large amounts of data efficiently. ML overcomes this by learning from data and making predictions without fixed rules. It is needed for the following reasons:

1. Solving Complex Business Problems
Traditional programming struggles with tasks like language understanding and medical diagnosis. ML learns from data and predicts outcomes easily.

Examples:

Image and speech recognition in healthcare.
Language translation and sentiment analysis.
2. Handling Large Volumes of Data
The internet generates huge amounts of data every day. Machine Learning processes and analyzes this data quickly by providing valuable insights and real time predictions.

Examples:

Fraud detection in financial transactions.
Personalized feed recommendations on Facebook and Instagram from billions of interactions.

    """
}

for file_path, content in sample_text.items():
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(content)

print("sample text created")
# Out:
# sample text created

# %% [markdown]
# ## Directory Loader

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files", 
    glob="**/*.txt", 
    loader_cls=TextLoader, 
    loader_kwargs={"encoding": "utf-8"},
    show_progress = False
)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\ML_intro.txt'}, page_content=' ML intro\nMachine Learning is a technique that allows computers to learn from data and make decisions without explicit programming. It works by identifying patterns in data and using them to make predictions. It is used in areas such as:\n\nImage Recognition\nSpeech Processing\nLanguage Translation\nRecommender Systems\n\nNeed for Machine Learning\nMachine Learning is important because traditional programming cannot handle complex tasks or large amounts of data efficiently. ML overcomes this by learning from data and making predictions without fixed rules. It is needed for the following reasons:\n\n1. Solving Complex Business Problems\nTraditional programming struggles with tasks like language understanding and medical diagnosis. ML learns from data and predicts outcomes easily.\n\nExamples:\n\nImage and speech recognition in healthcare.\nLanguage translation and sentiment analysis.\n2. Handling Large
# ...

# %%
# !pip install pymupdf

# %%
# !pip install pypdf

# %% [markdown]
# ## PDF files

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

dir_loader = DirectoryLoader(
    "../data/pdf_files",
    glob="**/*.pdf",
    loader_cls=PyPDFLoader,
    show_progress=False
)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Skia/PDF m149', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36', 'creationdate': '2026-07-04T08:49:34+00:00', 'title': 'NLP_Handbook_TG_CPGET_2026.md', 'moddate': '2026-07-04T08:49:34+00:00', 'source': '..\\data\\pdf_files\\NLP_Handbook_TG_CPGET_2026.pdf', 'total_pages': 17, 'page': 0, 'page_label': '1'}, page_content='Natural Language Processing — Revision Handbook\nTG CPGET 2026 Exam Preparation\nThis handbook covers all 8 topics from your syllabus: Language Processing & Python, Text\nCorpora & Lexical Resources, Processing Raw Text, Categorizing & Tagging Words,\nLearning to Classify Text, Deep Learning for NLP, Extracting Information from Text, and\nAnalysing Sentence Structure.\nEach section has: Concept (simple language) → Key Deﬁnitions/Formulas → Worked\nExamples → Practice Questions.\nTABLE OF CONTENTS\n1. Language Processing and Python\n2. Accessing Text Corpora and
# ...

# %% [markdown]
# ## EXCEL files

# %%
# !pip install langchain langchain-community pandas openpyxl xlwings

# %%
import pandas as pd

df = pd.read_excel(
    "../data/excel_files/Statistics Interview Questions.xlsx"
)

df.head()
# Out:
#    Unnamed: 0 Statistics for Data Science and Business Analysis  \
# 0         NaN                                          Glossary
# 1         NaN                                               NaN
# 2         NaN                                           Section
# 3         NaN                                                 1
# 4         NaN                                                 1
#
#              Unnamed: 2  Unnamed: 3  \
# 0                   NaN         NaN
# 1                   NaN         NaN
# 2                Lesson        Word
# 3  Population vs sample  population
# 4  Population vs sample      sample
#
#                                           Unnamed: 4
# 0                                                NaN
# 1                                                NaN
# 2                                         Definition
# 3  The collections of all items of interest to ou...
# 4             A subset of the population; denoted n.

# %%
import os

print(os.getcwd())
# Out:
# e:\RAG\notebook

# %%
import pandas as pd

df = pd.read_excel(
    "../data/excel_files/Statistics Interview Questions.xlsx",
    engine="openpyxl"
)

df.head()
# Out:
#    Unnamed: 0 Statistics for Data Science and Business Analysis  \
# 0         NaN                                          Glossary
# 1         NaN                                               NaN
# 2         NaN                                           Section
# 3         NaN                                                 1
# 4         NaN                                                 1
#
#              Unnamed: 2  Unnamed: 3  \
# 0                   NaN         NaN
# 1                   NaN         NaN
# 2                Lesson        Word
# 3  Population vs sample  population
# 4  Population vs sample      sample
#
#                                           Unnamed: 4
# 0                                                NaN
# 1                                                NaN
# 2                                         Definition
# 3  The collections of all items of interest to ou...
# 4             A subset of the population; denoted n.

# %%
df = pd.read_csv(
    "../data/excel_files/laptopPrice.csv",
)
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
documents = []

for index, row in df.iterrows():

    text = f"""
brand: {row['brand']}

processor_brand: {row['processor_brand']}

processor_name: {row['processor_name']}
"""

    doc = Document(
        page_content=text,
        metadata={
            "source": "laptopPrice.csv",
            "row": index
        }
    )

    documents.append(doc)

# %%
print(documents[0])
# Out:
# page_content='
# brand: ASUS
#
# processor_brand: Intel
#
# processor_name: Core i3
# ' metadata={'source': 'laptopPrice.csv', 'row': 0}

# %%
print(documents)
# Out:
# [Document(metadata={'source': 'laptopPrice.csv', 'row': 0}, page_content='\nbrand: ASUS\n\nprocessor_brand: Intel\n\nprocessor_name: Core i3\n'), Document(metadata={'source': 'laptopPrice.csv', 'row': 1}, page_content='\nbrand: Lenovo\n\nprocessor_brand: Intel\n\nprocessor_name: Core i3\n'), Document(metadata={'source': 'laptopPrice.csv', 'row': 2}, page_content='\nbrand: Lenovo\n\nprocessor_brand: Intel\n\nprocessor_name: Core i3\n'), Document(metadata={'source': 'laptopPrice.csv', 'row': 3}, page_content='\nbrand: ASUS\n\nprocessor_brand: Intel\n\nprocessor_name: Core i5\n'), Document(metadata={'source': 'laptopPrice.csv', 'row': 4}, page_content='\nbrand: ASUS\n\nprocessor_brand: Intel\n\nprocessor_name: Celeron Dual\n'), Document(metadata={'source': 'laptopPrice.csv', 'row': 5}, page_content='\nbrand: ASUS\n\nprocessor_brand: Intel\n\nprocessor_name: Celeron Dual\n'), Document(metadata={'source': 'laptopPrice.csv', 'row': 6}, page_content='\nbrand: ASUS\n\nprocessor_brand: Intel\
# ...

# %%
from langchain_core.documents import Document

documents = []

for index, row in df.iterrows():

    text = "\n".join(
        f"{column}: {row[column]}"
        for column in df.columns
    )

    doc = Document(
        page_content=text,
        metadata={
            "source": "laptopPrice.csv",
            "row": index
        }
    )

    documents.append(doc)

# %%
documents[0]
# Out:
# Document(metadata={'source': 'laptopPrice.csv', 'row': 0}, page_content='brand: ASUS\nprocessor_brand: Intel\nprocessor_name: Core i3\nprocessor_gnrtn: 10th\nram_gb: 4 GB\nram_type: DDR4\nssd: 0 GB\nhdd: 1024 GB\nos: Windows\nos_bit: 64-bit\ngraphic_card_gb: 0 GB\nweight: Casual\nwarranty: No warranty\nTouchscreen: No\nmsoffice: No\nPrice: 34649\nrating: 2 stars\nNumber of Ratings: 3\nNumber of Reviews: 0')

# %% [markdown]
# ## HTML files

# %%
# !pip install beautifulsoup4 requests

# %%
import requests
url = "https://www.geeksforgeeks.org/python-programming-language/"
response = requests.get(url)
html = response.text
print(html[:500])
# Out:
# <!DOCTYPE html><html lang="en"><head><link rel="preconnect" href="https://fonts.googleapis.com"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><meta charSet="UTF-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=0.5, maximum-scale=3.0"/><meta name="robots" content="index, follow, max-image-preview:large, max-snippet:-1"/><link rel="shortcut icon" href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" type=

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html,"html.parser")

# %%
text = soup.get_text()
print(text[:500])
# Out:
# Python Tutorial - GeeksforGeeksCoursesTutorialsPracticeJobsPython TutorialData TypesInterview QuestionsExamplesQuizzesDSA PythonData ScienceNumPyPandasPracticeDjangoFlaskShare Your ExperiencesPython FundamentalsIntroductionInput & OutputVariablesOperatorsKeywordsData TypesConditional StatementsLoopsFunctionsPython Data StructuresStringListTuplesDictionarySetArraysAdvanced PythonOOP ConceptsException HandlingFile HandlingPython DatabaseMongoDBMySQLPackagesModulesDSA LibrariesPython GUIData Scienc

# %%
paragraphs = soup.find_all("p")

for p in paragraphs[:5]:
    print(p.get_text())
# Out:
# Python is one of the most popular programming languages. It’s simple to use, packed with features and supported by a wide range of libraries and frameworks. Its clean syntax makes it beginner-friendly.
# The following is a simple program that displays the message “Hello, World!” on the screen.
# In this section, we’ll cover the basics of Python programming, including installation, writing first program, understanding comments and working with variables, keywords and operators. Before starting to learn python we need to install python on our system.
# In this section of Python 3 tutorial we'll explore Python function syntax, parameter handling, return values and variable scope. Along the way, we'll also introduce versatile functions like range(), map, filter and lambda functions.
# Python offers versatile collections of data types, including lists, string, tuples, sets, dictionaries and arrays. In this section, we will learn about each data types in detail.

# %%
headings = soup.find_all(["h1","h2","h3"])

for h in headings:
    print(h.get_text())
# Out:
# Python Tutorial
# Basic Code Example
# Why Learn Python?
# Basics
# Functions
# Data Structures
# OOP Concepts
# Exception Handling
# File Handling
# Database Handling
# Packages or Libraries
# Data Science
# Web Development
# Chapter-wise Practice Quiz
# Interview Questions and Practice Problems

# %%
document = Document(
    page_content=text,
    metadata={
        "source":url,
        "row":index
    }
)

print(document)
# Out:
# page_content='Python Tutorial - GeeksforGeeksCoursesTutorialsPracticeJobsPython TutorialData TypesInterview QuestionsExamplesQuizzesDSA PythonData ScienceNumPyPandasPracticeDjangoFlaskShare Your ExperiencesPython FundamentalsIntroductionInput & OutputVariablesOperatorsKeywordsData TypesConditional StatementsLoopsFunctionsPython Data StructuresStringListTuplesDictionarySetArraysAdvanced PythonOOP ConceptsException HandlingFile HandlingPython DatabaseMongoDBMySQLPackagesModulesDSA LibrariesPython GUIData Science with PythonNumpyPandasMatplotlibSeabornStatsModelModel BuildingTensorFlowPyTorchWeb Development with PythonFlaskDjangoDjango ORMJinja2 TemplatingDjango TemplatesREST APIBuild API with DRFPython PracticeQuizPractice ProblemsInterview Q & ACoursesPlacement 360 CourseData Analytics CourseDSA and System DesignSummer SkillUpExplorePython TutorialLast Updated : 14 Jul, 2026Python is one of the most popular programming languages. It’s simple to use, packed with features and supported 
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(
    "https://www.geeksforgeeks.org/python-programming-language/"
)

documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'source': 'https://www.geeksforgeeks.org/python-programming-language/', 'title': 'Python Tutorial - GeeksforGeeks', 'description': 'Your All-in-One Learning Portal: GeeksforGeeks is a comprehensive educational platform that empowers learners across domains-spanning computer science and programming, school education, upskilling, commerce, software tools, competitive exams, and more.', 'language': 'en'}, page_content='Python Tutorial - GeeksforGeeksCoursesTutorialsPracticeJobsPython TutorialData TypesInterview QuestionsExamplesQuizzesDSA PythonData ScienceNumPyPandasPracticeDjangoFlaskShare Your ExperiencesPython FundamentalsIntroductionInput & OutputVariablesOperatorsKeywordsData TypesConditional StatementsLoopsFunctionsPython Data StructuresStringListTuplesDictionarySetArraysAdvanced PythonOOP ConceptsException HandlingFile HandlingPython DatabaseMongoDBMySQLPackagesModulesDSA LibrariesPython GUIData Science with PythonNumpyPandasMatplotlibSeabornStatsModelModel B
# ...

# %%
with open(
    "../data/html_files/first.html",
    "r",
    encoding="utf-8"
) as f:
    html= f.read()

print(html[:500])
# Out:
# <!doctype html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>My Blog Document</title>
#   </head>
#   <body>
#     <h1>Welcome to My Blog</h1>
#
#     <p>RAG combines retrieval and generation.</p>
#
#     <a href="/contact">Contact Us</a>
#     <div class="container">
#       <h1>Machine Learning</h1>
#       <p>Machine learning is a subset of AI.</p>
#
#       <script>
#         alert("Hello");
#       </script>
#
#       <st

# %%
soup = BeautifulSoup(html,"html.parser")
text = soup.get_text(separator="\n", strip=True)
print(text)
# Out:
# My Blog Document
# Welcome to My Blog
# RAG combines retrieval and generation.
# Contact Us
# Machine Learning
# Machine learning is a subset of AI.

# %%
for tag in soup(["script", "style"]):
    tag.decompose()

text = soup.get_text(separator="\n", strip=True)

print(text)
# Out:
# My Blog Document
# Welcome to My Blog
# RAG combines retrieval and generation.
# Contact Us
# Machine Learning
# Machine learning is a subset of AI.

# %%
document = Document(
    page_content = text,
    metadata={
        "source": "first.html",
        "title" : "First HTML file"
    }
)

document
# Out:
# Document(metadata={'source': 'first.html', 'title': 'First HTML file'}, page_content='My Blog Document\nWelcome to My Blog\nRAG combines retrieval and generation.\nContact Us\nMachine Learning\nMachine learning is a subset of AI.')

# %% [markdown]
# - Read HTML File
# - Parse HTML
# - Remove unwanted tags
# - Extract text
# - Create Document
