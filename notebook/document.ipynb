# %% [markdown]
# # Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is a test document. main content to create rag",
    metadata={
        "source": "test.txt",
        "pages" : 1,
        "author" : "SK"
        }
)

# %%
doc
# Out:
# Document(metadata={'source': 'test.txt', 'pages': 1, 'author': 'SK'}, page_content='This is a test document. main content to create rag')

# %%
## Simple txt file

import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text = {
    "../data/text_files/python_intro.txt":""" Python programming intro
    Concept:
Data is raw, unprocessed facts — numbers, characters, or signals — that by themselves carry no context (e.g.,
72, 'Ravi', 08). Information is data that has been processed, organized, or structured so it becomes meaningful
and useful for decision-making (e.g., 'Ravi scored 72 marks on 08-06-2026'). The transformation of data into
information happens through processing: sorting, classifying, summarizing, and calculating. Key properties of
good information are accuracy, timeliness, completeness, relevance, and reliability. In the
data-information-knowledge-wisdom (DIKW) hierarchy, data sits at the base, information is data with context,
knowledge is information with understanding of patterns, and wisdom is knowledge applied with judgement.
CPGET frequently tests the distinction between data and information, examples of each, and characteristics of
quality information.

Practice Questions:
Q1. Which of the following is an example of 'information' rather than raw 'data'?
Solution: 'The average monthly rainfall in Hyderabad in June is 120 mm' is information because raw daily
rainfall readings have been processed (averaged) and given context. A single reading like '15 mm' alone is data.
Q2. List three properties that make information 'good quality' for decision-making.
Solution: Accuracy (free from errors), Timeliness (available when needed), and Relevance (applicable to the
decision at hand). Completeness and reliability are also acceptable answers.
Q3. Explain with one example how the same data can produce different information for different users.
Solution: Sales figures (data) of a shop can be processed into 'total monthly revenue' for an owner, or into
'best-selling product' for a marketing team — same raw data, different processing goals, different information.

Previous Year Questions:
1. Data can best be described as:\n(A) Processed facts \n(B) Raw, unorganized facts \n(C) Knowledge derived
from experience \n(D) A decision-making tool
Answer: (B)
2. Which term refers to data that has been given context and meaning?\n(A) Database \n(B) Information \n(C)Algorithm \n(D) Protocol
Answer: (B)
3. In the DIKW hierarchy, which level comes immediately above 'Data'?\n(A) Wisdom \n(B) Knowledge \n(C)Information \n(D) Intelligence
Answer: (C)

    """
}

for file_path, content in sample_text.items():
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(content)

print("sample text created")
# Out:
# sample text created

# %%
## Text loader

# from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# C:\Users\kotha\AppData\Local\Temp\ipykernel_9524\3599593742.py:4: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content=" Python programming intro\n    Concept:\nData is raw, unprocessed facts — numbers, characters, or signals — that by themselves carry no context (e.g.,\n72, 'Ravi', 08). Information is data that has been processed, organized, or structured so it becomes meaningful\nand useful for decision-making (e.g., 'Ravi scored 72 marks on 08-06-2026'). The transformation of data into\ninformation happens through processing: sorting, classifying, summarizing, and calculating. Key properties of\ngood information are accuracy, timeliness, completeness, relevance, and reliability. In the\ndata-information-knowledge-wisdom (DIKW) hierarchy, data sits at the base, information is data with context,\nknowledge is information with understanding of patterns, and wisdom is knowledge applied with judgement.\nCPGET frequently tests the distinction between data and information, examples of each, and characteristics of\nquality information.\n\nPractice Questions:\nQ1. Which of the following is an example of 'information' rather than raw 'data'?\nSolution: 'The average monthly rainfall in Hyderabad in June is 120 mm' is information because raw daily\nrainfall readings have been processed (averaged) and given context. A single reading like '15 mm' alone is data.\nQ2. List three properties that make information 'good quality' for decision-making.\nSolution: Accuracy (free from errors), Timeliness (available when needed), and Relevance (applicable to the\ndecision at hand). Completeness and reliability are also acceptable answers.\nQ3. Explain with one example how the same data can produce different information for different users.\nSolution: Sales figures (data) of a shop can be processed into 'total monthly revenue' for an owner, or into\n'best-selling product' for a marketing team — same raw data, different processing goals, different information.\n\nPrevious Year Questions:\n1. Data can best be described as:\n(A) Processed facts \n(B) Raw, unorganized facts \n(C) Knowledge derived\nfrom experience \n(D) A decision-making tool\nAnswer: (B)\n2. Which term refers to data that has been given context and meaning?\n(A) Database \n(B) Information \n(C)Algorithm \n(D) Protocol\nAnswer: (B)\n3. In the DIKW hierarchy, which level comes immediately above 'Data'?\n(A) Wisdom \n(B) Knowledge \n(C)Information \n(D) Intelligence\nAnswer: (C)\n\n    ")]

# %%
# !pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (1.4.8)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (0.9.4)
# Requirement already satisfied: numpy>=2.1.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (2.4.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\kotha\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.14.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.8.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: certifi in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.7.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\kotha\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.3)
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sample_text = {
    "../data/text_files/ML_intro.txt":""" ML intro
Machine Learning is a technique that allows computers to learn from data and make decisions without explicit programming. It works by identifying patterns in data and using them to make predictions. It is used in areas such as:

Image Recognition
Speech Processing
Language Translation
Recommender Systems

Need for Machine Learning
Machine Learning is important because traditional programming cannot handle complex tasks or large amounts of data efficiently. ML overcomes this by learning from data and making predictions without fixed rules. It is needed for the following reasons:

1. Solving Complex Business Problems
Traditional programming struggles with tasks like language understanding and medical diagnosis. ML learns from data and predicts outcomes easily.

Examples:

Image and speech recognition in healthcare.
Language translation and sentiment analysis.
2. Handling Large Volumes of Data
The internet generates huge amounts of data every day. Machine Learning processes and analyzes this data quickly by providing valuable insights and real time predictions.

Examples:

Fraud detection in financial transactions.
Personalized feed recommendations on Facebook and Instagram from billions of interactions.

    """
}

for file_path, content in sample_text.items():
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(content)

print("sample text created")
# Out:
# sample text created

# %%
## Directory Loader

from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files", 
    glob="**/*.txt", 
    loader_cls=TextLoader, 
    loader_kwargs={"encoding": "utf-8"},
    show_progress = False
)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\ML_intro.txt'}, page_content=' ML intro\nMachine Learning is a technique that allows computers to learn from data and make decisions without explicit programming. It works by identifying patterns in data and using them to make predictions. It is used in areas such as:\n\nImage Recognition\nSpeech Processing\nLanguage Translation\nRecommender Systems\n\nNeed for Machine Learning\nMachine Learning is important because traditional programming cannot handle complex tasks or large amounts of data efficiently. ML overcomes this by learning from data and making predictions without fixed rules. It is needed for the following reasons:\n\n1. Solving Complex Business Problems\nTraditional programming struggles with tasks like language understanding and medical diagnosis. ML learns from data and predicts outcomes easily.\n\nExamples:\n\nImage and speech recognition in healthcare.\nLanguage translation and sentiment analysis.\n2. Handling Large Volumes of Data\nThe internet generates huge amounts of data every day. Machine Learning processes and analyzes this data quickly by providing valuable insights and real time predictions.\n\nExamples:\n\nFraud detection in financial transactions.\nPersonalized feed recommendations on Facebook and Instagram from billions of interactions.\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content=" Python programming intro\n    Concept:\nData is raw, unprocessed facts — numbers, characters, or signals — that by themselves carry no context (e.g.,\n72, 'Ravi', 08). Information is data that has been processed, organized, or structured so it becomes meaningful\nand useful for decision-making (e.g., 'Ravi scored 72 marks on 08-06-2026'). The transformation of data into\ninformation happens through processing: sorting, classifying, summarizing, and calculating. Key properties of\ngood information are accuracy, timeliness, completeness, relevance, and reliability. In the\ndata-information-knowledge-wisdom (DIKW) hierarchy, data sits at the base, information is data with context,\nknowledge is information with understanding of patterns, and wisdom is knowledge applied with judgement.\nCPGET frequently tests the distinction between data and information, examples of each, and characteristics of\nquality information.\n\nPractice Questions:\nQ1. Which of the following is an example of 'information' rather than raw 'data'?\nSolution: 'The average monthly rainfall in Hyderabad in June is 120 mm' is information because raw daily\nrainfall readings have been processed (averaged) and given context. A single reading like '15 mm' alone is data.\nQ2. List three properties that make information 'good quality' for decision-making.\nSolution: Accuracy (free from errors), Timeliness (available when needed), and Relevance (applicable to the\ndecision at hand). Completeness and reliability are also acceptable answers.\nQ3. Explain with one example how the same data can produce different information for different users.\nSolution: Sales figures (data) of a shop can be processed into 'total monthly revenue' for an owner, or into\n'best-selling product' for a marketing team — same raw data, different processing goals, different information.\n\nPrevious Year Questions:\n1. Data can best be described as:\n(A) Processed facts \n(B) Raw, unorganized facts \n(C) Knowledge derived\nfrom experience \n(D) A decision-making tool\nAnswer: (B)\n2. Which term refers to data that has been given context and meaning?\n(A) Database \n(B) Information \n(C)Algorithm \n(D) Protocol\nAnswer: (B)\n3. In the DIKW hierarchy, which level comes immediately above 'Data'?\n(A) Wisdom \n(B) Knowledge \n(C)Information \n(D) Intelligence\nAnswer: (C)\n\n    ")]

# %%
## PDF files 

from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

dir_loader = DirectoryLoader(
    "../data/pdf_files",
    glob="**/*.pdf",
    loader_cls=PyPDFLoader,
    loader_kwargs={"encoding": "utf-8"},
    show_progress=False
)
